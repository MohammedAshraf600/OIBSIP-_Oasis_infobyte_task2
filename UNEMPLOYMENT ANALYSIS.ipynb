# %% [markdown]
# # Name:Mohammed Ashraf

# %% [markdown]
# # Company:Oasis Infobyte

# %% [markdown]
# # Project:UNEMPLOYMENT ANALYSIS

# %%
#for data preprocessing
import pandas as pd
import numpy as np
#for data visualization
import matplotlib.pyplot as plot
import seaborn as sns

# %%
import warnings
# Ignore all warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Task:
# Laptop with Browser Icon
# Unemployment is measured by the unemployment rate which is the number of people
# who are unemployed as a percentage of the total labour force. We have seen a sharp
# increase in the unemployment rate during Covid-19, so analyzing the unemployment rate
# can be a good data science project.
#
# # describtion :
# 1-Region: This column likely contains information about the geographical region associated with the data points. It could represent the location or area from which the other data is derived.
#
# 2-Date: This column likely contains date values, representing the time when the data was recorded or measured. It is likely to be in a datetime format.
#
# 3-Frequency: This column might indicate the frequency at which the data is collected or reported. It could be daily, monthly, yearly, or some other time interval.
#
# 4-Estimated Unemployment Rate (%): This column probably contains numerical values representing the estimated unemployment rate as a percentage. This rate typically indicates the proportion of unemployed individuals in the workforce.
#
# 5-Estimated Employed: This column likely contains numerical values representing the estimated number of employed individuals. It provides information about the size of the employed workforce.
#
# 6-Estimated Labour Participation Rate (%): This column probably contains numerical values representing the estimated labor participation rate as a percentage. This rate typically indicates the proportion of the working-age population that is either employed or actively seeking employment.
#
# 7-Area: This column likely contains information about the specific area or location associated with the data. It may provide additional details about the geographic scope of the information.

# %%
#load our data 
df = pd.read_csv("Unemployment in India.csv")

# %%
#see our data
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
#read the first row 
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
#read the last row
df.tail()
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 763    NaN   NaN        NaN                               NaN
# 764    NaN   NaN        NaN                               NaN
# 765    NaN   NaN        NaN                               NaN
# 766    NaN   NaN        NaN                               NaN
# 767    NaN   NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area
# 763                  NaN                                       NaN  NaN
# 764                  NaN                                       NaN  NaN
# 765                  NaN                                       NaN  NaN
# 766                  NaN                                       NaN  NaN
# 767                  NaN                                       NaN  NaN

# %%
#size of our data
df.size
# Out:
# 5376

# %%
#shape of our data 
df.shape
# Out:
# (768, 7)

# %%
#information about our data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
#describtion about our data
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
df.dtypes
# Out:
# Region                                       object
#  Date                                        object
#  Frequency                                   object
#  Estimated Unemployment Rate (%)            float64
#  Estimated Employed                         float64
#  Estimated Labour Participation Rate (%)    float64
# Area                                         object
# dtype: object

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %% [markdown]
# # data preprocessing

# %%
#check duplicated values
df.duplicated().sum()
# Out:
# 27

# %%
#let's drop duplicated values
df=df.drop_duplicates()

# %%
#check after drop duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
#checking our data if there are nulls or not 
df.isnull().sum()
# Out:
# Region                                      1
#  Date                                       1
#  Frequency                                  1
#  Estimated Unemployment Rate (%)            1
#  Estimated Employed                         1
#  Estimated Labour Participation Rate (%)    1
# Area                                        1
# dtype: int64

# %%
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
# we will deal with miss values by Mean&Mode&Median
# Filling missing values with the mean of each respective column
df[' Estimated Unemployment Rate (%)'] = df[' Estimated Unemployment Rate (%)'].fillna(df[' Estimated Unemployment Rate (%)'].mean())
df[' Estimated Employed'] = df[' Estimated Employed'].fillna(df[' Estimated Employed'].mean())
df[' Estimated Labour Participation Rate (%)'] = df[' Estimated Labour Participation Rate (%)'].fillna(df[' Estimated Labour Participation Rate (%)'].mean())

# %%
df['Region'] = df['Region'].fillna(df['Region'].mode().iloc[0])
df[' Date'] = df[' Date'].fillna(df[' Date'].mode().iloc[0])
df['Area'] = df['Area'].fillna(df['Area'].mode().iloc[0])
df[' Frequency'] = df[' Frequency'].fillna(df[' Frequency'].mode().iloc[0])

# %%
#checking our data after dealing with null_values
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
#split Date into Day&month&year 
df[' Date'] = pd.to_datetime(df[' Date'])
# Extracting day, month, and year into new columns using .loc
df['day'] = df[' Date'].dt.day
df['month'] = df[' Date'].dt.month
df['year'] = df[' Date'].dt.year

# %%
#my data after spiltting Date
df.head()
# Out:
#            Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31    Monthly                              3.65
# 1  Andhra Pradesh 2019-06-30    Monthly                              3.05
# 2  Andhra Pradesh 2019-07-31    Monthly                              3.75
# 3  Andhra Pradesh 2019-08-31    Monthly                              3.32
# 4  Andhra Pradesh 2019-09-30    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area  day  \
# 0           11999139.0                                     43.24  Rural   31
# 1           11755881.0                                     42.05  Rural   30
# 2           12086707.0                                     43.50  Rural   31
# 3           12285693.0                                     43.97  Rural   31
# 4           12256762.0                                     44.68  Rural   30
#
#    month  year
# 0      5  2019
# 1      6  2019
# ...

# %%
#change the type of Estimated Unemployment Rate & Estimated Labour Participation Rate & Estimated Employed from float to int
df[' Estimated Unemployment Rate (%)'] = df[' Estimated Unemployment Rate (%)'].astype(int)
df[' Estimated Labour Participation Rate (%)'] = df[' Estimated Labour Participation Rate (%)'].astype(int)
df[' Estimated Employed'] = df[' Estimated Employed'].astype(int)

# %%
#let's check the dypes of our data
df.dtypes
# Out:
# Region                                              object
#  Date                                       datetime64[ns]
#  Frequency                                          object
#  Estimated Unemployment Rate (%)                     int32
#  Estimated Employed                                  int32
#  Estimated Labour Participation Rate (%)             int32
# Area                                                object
# day                                                  int32
# month                                                int32
# year                                                 int32
# dtype: object

# %%
# let's see our data after data preprocessing
df
# Out:
#              Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31    Monthly                                 3
# 1    Andhra Pradesh 2019-06-30    Monthly                                 3
# 2    Andhra Pradesh 2019-07-31    Monthly                                 3
# 3    Andhra Pradesh 2019-08-31    Monthly                                 3
# 4    Andhra Pradesh 2019-09-30    Monthly                                 5
# ..              ...        ...        ...                               ...
# 749     West Bengal 2020-02-29    Monthly                                 7
# 750     West Bengal 2020-03-31    Monthly                                 6
# 751     West Bengal 2020-04-30    Monthly                                15
# 752     West Bengal 2020-05-31    Monthly                                15
# 753     West Bengal 2020-06-30    Monthly                                 9
#
# ...

# %% [markdown]
# # let's detect outliers

# %%
#visualizatoin to see the outliers

fig, ax = plot.subplots(2, 2, figsize=(8, 12))

# Boxplot for Estimated Unemployment Rate (%)
ax[0, 0].boxplot(x=df[[' Estimated Unemployment Rate (%)']])
ax[0, 0].set_title('Estimated Unemployment Rate (%)')

# Boxplot for Estimated Employed
ax[0, 1].boxplot(x=df[[' Estimated Employed']])
ax[0, 1].set_title('Estimated Employed')

# Boxplot for Estimated Labour Participation Rate (%)
ax[1, 0].boxplot(x=df[[' Estimated Labour Participation Rate (%)']])
ax[1, 0].set_title('Estimated Labour Participation Rate (%)')

# Remove the last subplot (ax[1, 1]) from the layout
fig.delaxes(ax[1, 1])

plot.show()

# %%
#Q1 and Q3 calculations, and the interquartile range (IQR) for the 'Estimated Unemployment Rate (%)'
Q1_Estimated_Unemployment_Rate=df[' Estimated Unemployment Rate (%)'].quantile(0.25)
Q3_Estimated_Unemployment_Rate=df[' Estimated Unemployment Rate (%)'].quantile(0.75)
IQR_Estimated_Unemployment_Rate=Q3_Estimated_Unemployment_Rate - Q1_Estimated_Unemployment_Rate
print(IQR_Estimated_Unemployment_Rate)
# Out:
# 11.0

# %%
df = df [~((df[' Estimated Unemployment Rate (%)']<(Q1_Estimated_Unemployment_Rate-1.5*IQR_Estimated_Unemployment_Rate))|(df[' Estimated Unemployment Rate (%)']>(Q3_Estimated_Unemployment_Rate+1.5*IQR_Estimated_Unemployment_Rate)))]

# %%
#let's visualize after detecting outliers in Estimated Unemployment Rate (%)
sns.boxplot(x=' Estimated Unemployment Rate (%)', data=df)
# Out:
# <Axes: xlabel=' Estimated Unemployment Rate (%)'>

# %%
#Q1 and Q3 calculations, and the interquartile range (IQR) for the 'Estimated Employed'
Q1_Estimated_Employed=df[' Estimated Employed'].quantile(0.25)
Q3_Estimated_Employed=df[' Estimated Employed'].quantile(0.75)
IQR_Estimated_Employed=Q3_Estimated_Employed - Q1_Estimated_Employed
print(IQR_Estimated_Employed)
# Out:
# 10138940.0

# %%
df = df [~((df[' Estimated Employed']<(Q1_Estimated_Employed-1.5*IQR_Estimated_Employed))|(df[' Estimated Employed']>(Q3_Estimated_Employed+1.5*IQR_Estimated_Employed)))]

# %%
#let's visualize after detecting outliers in Estimated Employed
sns.boxplot(x=' Estimated Employed', data=df)
# Out:
# <Axes: xlabel=' Estimated Employed'>

# %%
#Q1 and Q3 calculations, and the interquartile range (IQR) for the 'Estimated Labour Participation Rate (%)'
Q1_Estimated_Labour_Participation_Rate=df[' Estimated Labour Participation Rate (%)'].quantile(0.25)
Q3_Estimated_Labour_Participation_Rate=df[' Estimated Labour Participation Rate (%)'].quantile(0.75)
IQR_Estimated_Labour_Participation_Rate=Q3_Estimated_Labour_Participation_Rate - Q1_Estimated_Labour_Participation_Rate
print(IQR_Estimated_Labour_Participation_Rate)
# Out:
# 7.0

# %%
df = df [~((df[' Estimated Labour Participation Rate (%)']<(Q1_Estimated_Labour_Participation_Rate-1.5*IQR_Estimated_Labour_Participation_Rate))|(df[' Estimated Labour Participation Rate (%)']>(Q3_Estimated_Labour_Participation_Rate+1.5*IQR_Estimated_Labour_Participation_Rate)))]

# %%
#let's visualize after detecting outliers in Estimated Labour Participation Rate (%)
sns.boxplot(x=' Estimated Labour Participation Rate (%)', data=df)
# Out:
# <Axes: xlabel=' Estimated Labour Participation Rate (%)'>

# %%
df.head()
# Out:
#            Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31    Monthly                                 3
# 1  Andhra Pradesh 2019-06-30    Monthly                                 3
# 2  Andhra Pradesh 2019-07-31    Monthly                                 3
# 3  Andhra Pradesh 2019-08-31    Monthly                                 3
# 4  Andhra Pradesh 2019-09-30    Monthly                                 5
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area  day  \
# 0             11999139                                        43  Rural   31
# 1             11755881                                        42  Rural   30
# 2             12086707                                        43  Rural   31
# 3             12285693                                        43  Rural   31
# 4             12256762                                        44  Rural   30
#
#    month  year
# 0      5  2019
# 1      6  2019
# ...

# %% [markdown]
# # Data visualization

# %%
#graph between 'Estimated Unemployment Rate (%)' and 'Region'
plot.figure(figsize=(45, 20))
sns.barplot(x='Region', y=' Estimated Unemployment Rate (%)', data=df)
plot.title('Bar Graph: Estimated Unemployment Rate (%) by Region')
plot.xlabel('Region')
plot.ylabel('Estimated Unemployment Rate (%)')
plot.show()

# %%
#graph between 'Estimated Labour Participation Rate (%)' and 'Region'
plot.figure(figsize=(45, 20))
sns.barplot(x='Region', y=' Estimated Labour Participation Rate (%)', data=df)
plot.title('Bar Graph: Estimated Labour Participation Rate (%) by Region')
plot.xlabel('Region')
plot.ylabel('Estimated Labour Participation Rate (%)')
plot.show()

# %%
#the visualization Distribution of Regions
region_counts = df['Region'].value_counts()
plot.figure(figsize=(25, 25))
plot.pie(region_counts, labels=region_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#99ff99', '#ffcc99', '#ff6666'])
plot.title('Distribution of Regions')
plot.show()

# %%
#graph between 'Estimated Unemployment Rate (%)' and 'Area'
plot.figure(figsize=(12, 6))
sns.barplot(x='Area', y=' Estimated Unemployment Rate (%)', data=df)
plot.title('Bar Graph: Estimated Unemployment Rate (%) by Area')
plot.xlabel('Area')
plot.ylabel('Estimated Unemployment Rate (%)')
plot.show()

# %%
#graph between 'Estimated Labour Participation Rate (%)' and 'Area'
plot.figure(figsize=(12, 6))
sns.barplot(x='Area', y=' Estimated Labour Participation Rate (%)', data=df)
plot.title('Bar Graph: Estimated Labour Participation Rate (%) by Area')
plot.xlabel('Area')
plot.ylabel('Estimated Labour Participation Rate (%)')
plot.show()

# %%
#the visualization Distribution of Areas
region_counts = df['Area'].value_counts()
plot.figure(figsize=(8, 8))
plot.pie(region_counts, labels=region_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#99ff99'])
plot.title('Distribution of Areas')
plot.show()

# %%
#graph between 'Estimated Unemployment Rate (%)' and 'year'
plot.figure(figsize=(12, 6))
sns.barplot(x='year', y=' Estimated Unemployment Rate (%)', data=df)
plot.title('Bar Graph: Estimated Unemployment Rate (%) by year')
plot.xlabel('year')
plot.ylabel('Estimated Unemployment Rate (%)')
plot.show()

# %%
#graph between 'Estimated Labour Participation Rate (%)' and 'Area'
plot.figure(figsize=(12, 6))
sns.barplot(x='year', y=' Estimated Labour Participation Rate (%)', data=df)
plot.title('Bar Graph: Estimated Labour Participation Rate (%) by year')
plot.xlabel('year')
plot.ylabel('Estimated Labour Participation Rate (%)')
plot.show()

# %%
df.head()
# Out:
#            Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31    Monthly                                 3
# 1  Andhra Pradesh 2019-06-30    Monthly                                 3
# 2  Andhra Pradesh 2019-07-31    Monthly                                 3
# 3  Andhra Pradesh 2019-08-31    Monthly                                 3
# 4  Andhra Pradesh 2019-09-30    Monthly                                 5
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area  day  \
# 0             11999139                                        43  Rural   31
# 1             11755881                                        42  Rural   30
# 2             12086707                                        43  Rural   31
# 3             12285693                                        43  Rural   31
# 4             12256762                                        44  Rural   30
#
#    month  year
# 0      5  2019
# 1      6  2019
# ...

# %%
df[' Estimated Employed']
# Out:
# 0      11999139
# 1      11755881
# 2      12086707
# 3      12285693
# 4      12256762
#          ...
# 749    10871168
# 750    10806105
# 751     9299466
# 752     9240903
# 753     9088931
# Name:  Estimated Employed, Length: 629, dtype: int32

# %%
#visualization of the number of employees per month
data = df.groupby('month')[' Estimated Employed'].mean()
data  = pd.DataFrame({'month':data.index,'Average_Estimated_Employed':data.values})
plot.figure(figsize = (10,5))
plot.plot('month','Average_Estimated_Employed','ys-',data = data);
plot.grid();
plot.xlabel('month group');
plot.ylabel('Average_Estimated_Employed');
plot.title('month group vs Average Estimated Employed');

# %% [markdown]
# # Thanks Oasis infobyte
